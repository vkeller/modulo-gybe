# %% [markdown]
# ![rev](images/rev1.png "en-tête")
#
# # R1-ALGO-03 : Rappels algorigrammes - Python

# %% [markdown]
# ## Objectifs pédagogiques
#
# - Réviser la construction d'un algorigramme
#     - tests conditionnels
#     - boucles
#     - entrées sorties
# - Réviser la mise en oeuvre d'un programme Python

# %% [markdown]
# ## Algorigrammes : symboles et code Python correspondant
#
# ### Début et Fin
# ![debut](schemas/debut.png "algo debut")
#
# *Première ligne du programme*
#
# ![fin](schemas/fin.png "algo fin")
#
# *Dernière ligne du programme*
#
# ### Entrées
#
# ![input](schemas/input.png "algo entrée")
#
# ```python
# nomDeLaVariable = input("Entrez une valeur : ")
# ```
#
# ### Sorties
#
# ![output](schemas/output.png "algo sortie")
#
# ```python
# print("Une chaîne de caractères",uneVariable)
# ```
#
# ### Instruction/Opération
#
# ![instruction](schemas/instruction.png "algo instruction")
#
# ```python
# c = a + b
# ```
#
#
#
# ### Tests conditionnels
#
# ![test](schemas/test.png "algo test")
#
# ```python
# if condition :
#     ...
# else:
#     ...
# ```
#
# ### Boucles
#
# ![loop](schemas/loop.png "algo boucle")
#
# **Avec une boucle while**
#
# ```python
# start =
# stop =
# step =
# i = start
#
# while i < stop:
#     ...
#     i = i + 1
# ```
#
# **Avec une boucle for**
#
# ```python
# start =
# stop =
# step =
#
# for i in range(start, stop, step):
#     ...
# ```
