# %% [markdown]
# ![esdn2026](images/esdn-copilot.png "Image prétexte")
#
# *Image générée avec MS Copilot*
#
# # TP2-ESDN-2026 : Enjeux sociaux du numérique

# %% [markdown]
# ## Objectifs
#
# - Présenter les enjeux sociaux ainsi que les objectifs de l'évaluation
# - Comprendre la méthode
# - Créer les groupes de 2 ou 3 élèves
# - Choisir les dates des exposés

# %% [markdown]
# ## Méthode
#
# Elle se déroulera en 7 étapes:
#
# 1. Choisir un sujet pour l'exposé ayant trait aux enjeux sociaux du numérique
# 2. Recherche d'informations
# 3. Ecrire son exposé
# 4. Utilisation de l'IA générative pour évaluer son exposé
# 5. Préparer 8 questions
# 6. Présenter son exposé et tester ses camarades
# 7. Prendre des notes

# %% [markdown]
# ## Utilisation de l'IAg
#
# Il est tout à fait autorisé de faire ce travail **sans intelligence artificielle**.

# %% [markdown]
# ### 1. Choisir un sujet
#
# La liste trouve son origine sur le site de [mon collègue David Müller du lycée de Porrentruy](https://www.apprendre-en-ligne.net/societe/index.html). Elle a été étendue
#
# | # | Sujet | Thème | Ressource fiable |
# |---|-------|-------|-----------------|
# | 1 | Assistants vocaux et vie privée | Vie privée, données et surveillance | [CNIL - « Assistants vocaux : quels risques ? »](https://www.cnil.fr/fr/assistants-vocaux-les-conseils-pour-les-utilisateurs-et-les-professionnels) |
# | 2 | Géolocalisation : entre service et surveillance | Vie privée, données et surveillance | [CNIL - « Géolocalisation et vie privée »](https://www.cnil.fr/fr/partage-geolocalisation-conseils-de-la-cnil) |
# | 3 | Reconnaissance faciale : sécurité ou surveillance de masse ? | Vie privée, données et surveillance | [CNIL - « Reconnaissance faciale »](https://www.cnil.fr/fr/tag/reconnaissance-faciale) |
# | 4 | Surveillance numérique : sécurité vs libertés | Vie privée, données et surveillance | [Amnesty France - « Surveillance de masse »](https://www.amnesty.org/fr/latest/campaigns/2015/03/easy-guide-to-mass-surveillance/) |
# | 5 | Vie privée : protection des données personnelles | Vie privée, données et surveillance | [CNIL - Données personnelles](https://www.cnil.fr/fr/guide-de-la-securite-des-donnees-personnelles) |
# | 6 | ChatGPT et l'avenir de l'éducation | IA et algorithmes | [CNIL - FAQ IA à l'école](https://www.cnil.fr/fr/deux-faq-utilisation-des-systemes-dia-scolaire) |
# | 7 | Biais algorithmiques et discrimination | IA et algorithmes | [TélécomParis "biais, discrimination et équité des algorithmes"](https://telecom-paris.hal.science/hal-02077745/) |
# | 8 | Fausses images et désinformation visuelle | IA et algorithmes | [UNESCO - « Les deepfakes et la crise du savoir »](https://www.unesco.org/fr/articles/les-deepfakes-et-la-crise-du-savoir) |
# | 9 | Fake news : repérage et vérification | Médias et désinformation | [Le Monde - Vérification](https://www.lemonde.fr/verification/) |
# | 10 | Modération des contenus : qui décide ? | Médias et désinformation | [Conseil de l'Europe](https://rm.coe.int/content-moderation-fr/1680a40294) |
# | 11 | Cancel culture et liberté d'expression | Médias et désinformation | [Centre AVEC](https://www.centreavec.be/publication/cancel-culture-et-liberte-dexpression-nos-democraties-sont-elles-en-peril/) |
# | 12 | Influenceurs : modèles et responsabilité | Médias et désinformation | [The Conversation - Influence responsable](https://theconversation.com/entre-paillettes-et-ethique-linfluence-responsable-est-elle-un-mirage-279235) |
# | 32 | Death tech : le numérique face à la mort | Santé, éthique et transhumanisme | [apprendre-en-ligne.net](https://www.apprendre-en-ligne.net/societe/death_tech/index.html) |

# %% [markdown]
# ### 2. Recherche d'information
#
# Pour chaque sujet, une source est proposée. Attention, elle n'est pas unique et d'autres existent.
#
# **N'utilisez pas une IAg pour la RECHERCHE d'information, mais un moteur de recherche** (google sans gemini, google scholar, etc..)
#
# Regroupez toutes vos informations et sources dans un document word. Ce document word (exporté en PDF) doit **contenir au minimum 3 sources fiables**

# %% [markdown]
# ### 3. Ecrire son exposé
#
# A partir des sources que vous aurez lues, écrivez une première ébauche de votre exposé.
#
# **Il existe des outils d'IA pour cette étape**, [Google Notebook LM](https://notebooklm.google/) en est un ! NotebookLM est une IA qui permet des productions sur la base de sa propre liste de sources fiables.
#
# **LISEZ** votre exposé et vérifiez qu'il ne contient pas d'erreur. Produisez-en un PDF

# %% [markdown]
# ### 4. Auto-évaluation (IAg)
#
# Demandez à une IAg (ChatGPT, QWen, Perplexity, Gemini, etc..) d'évaluer votre production. Vous pouvez utiliser un prompt tel que :
#
# > Tu es un professeur dans un gymnase. Tu dois superviser un travail fait par un élève sur le sujet "Enjeux sociaux du numérique". Tu vas évaluer son travail (un fichier pdf que je vais t'envoyer) selon 3 critères :
# > 1. Quantité d'information : y a-t-il suffisamment de matières pour faire un exposé de 10 minutes? En particulier, y a-t-il des exemples concrets ?
# > 2. Qualité du contenu : exactitude, pertinence
# > 3. Organisation et clarté
# >
# > Pour chacun des critères, justifie brièvement tes points.

# %% [markdown]
# ### 5. Préparer 8 questions
#
# Il vous faudra trouver 8 questions assez difficiles à poser à la classe une fois l'exposé terminé. A nouveau ChatGPT peut vous aider :
#
# > Voici un pdf de mon exposé. Trouve 8 questions assez difficiles à partir de ce document. Propose 4 réponses plausibles pour chaque question.
#
# Consigne :
#
# 1. Préparer un Powerpoint de 16 slides (question 1, réponse 1, question 2, réponse 2, etc..)
# 2. Laisser le temps aux camarades de répondre
#
# **L'enseignant posera lui aussi des questions**

# %% [markdown]
# ### 6. Présenter son exposé
#
# Vous avez le droit à votre feuille d'exposé, mais il ne doit pas être lu.
#
# Timing :
#
# - 10 min de présentation
# - 4 min pour les questions (30 secondes par question)

# %% [markdown]
# ### 7. Prendre des notes
#
# C'est le point **crucial**. Les auditeurs (les camarades de la classe) devront prendre des notes dans un cahier spécifique acquis pour l'occasion.
#
# **Ce cahier sera le seul matériel autorisé pour l'évaluation !!!**
#
# La prise de notes manuscrite présente plusieurs avantages, notamment celui de mémoriser plus facilement.

# %% [markdown]
# ## Traces à envoyer à l'enseignant (20h LE SOIR PRÉCÉDENT L'EXPOSÉ)
#
# 1. Le PDF de l'exposé
# 2. Le PDF avec au minimum 3 sources
# 3. Le Powerpoint avec les 8 questions et les 8 réponses qui se suivent
# 4. L'auto-évaluation de ChatGPT (prompt + réponse de l'IAg)

# %% [markdown]
# ## EVALUATION
#
# L'évaluation se fera en classe sous la forme d'un QCM. Le QCM sera formé d'un choix de 3 questions par exposé. S'il y a eu 8 groupes, alors il y aura 24 questions
#
# Seul matériel autorisé : **le cahier de prises de notes**
