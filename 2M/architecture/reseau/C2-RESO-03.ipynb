# %% [markdown]
# ![hackeuse](images/hackeuse2.png "Haceuse")
#
# (image générée par IA)
#
# # C2-RESO-03 : Le Dark Net... bien ou mal ?

# %% [markdown]
# ## Objectifs pédagogiques
#
# - définir les différents services du Dark Net
# - comprendre l'architectude du Dark Net
# - connaître les avantages du Dark Net
# - connaître les dangers du Dark Net

# %% [markdown]
# ## Dark Net ? Kézako ?
#
# Il est d'usage de représenter l'ensemble des services, sites et éléments d'internet sous la forme d'un iceberg:
#
# ![tor-network](images/iceberg.png "Iceberg model")
#
# ([souce de l'image](https://www.trendmicro.com/fr_fr/what-is/dark-web/deep-web-vs-dark-web.html))
#
# Au niveau du Dar Net, le fonctionnement se matérialise par la création d'un chemin variant entre plusieurs noeuds d'un réseau construit au-dessus du réseau clair. Les communnications sont cryptées
#
# ![tor-network](images/tor-network.png "How it works ?")

# %% [markdown]
# ## A quoi ça sert le Dark Net ?
#
# Il existe un certain nombre de situations où un anonymat complet est requis. Cela va de la protection de la personnalité voir à la vie.
#
# 1. **Protection de la vie privée** : les outils permettant d'accéder au réseau TOR permet ensuite aux utilisateurs de surfer anonymement. Cela protège de la surveillance de masse, du pistage publicitaire et de l'espionnage gouvernemental
# 2. **Liberté d'expression dans les régime autoritaires** : des journalistes et des citoyens vivants dans des régimes autoritaires utilisent les outils permettant d'accéder au Dark Net pour accéder ou transmettre de l'information sans crainte de représailles
# 3. **Accès à des services sécurisés** : la plupart des grands médias reconnus et légitimes proposent des services (open source) de fuite d'information sécurisés (ex: RTS, New York Times, The Washington Post, etc..)
# 4. **Contournement de la censure internet** : dans certains pays, le trafic internet est fortement filtré (ex: Chine, Iran) s'il n'est pas complètement fermé (ex: Corée du Nord). Le réseau Tor notamment permet d'accéder à des services et contenus bloqués par les gouvernements.
# 5. **Journalisme d'investigation et enquêtes policières** : pour étudier ou enquêter sur des activités illégales
#
# Il existe néanmoins nombre d'éléments que cet anonymat permet et qui sont problématiques :
#
# 1. **Commerce illégal** : marchés clandestins où sont vendus des éléments matériels ou immatériels illégaux : drogue, armes, données volées, etc..
# 2. **Diffusion de contenu illicite ou choquant** : certains sites hébergent des contenus extrêmes (pornographie, violence, extrêmisme)
# 3. **Blanchiment d'argent et fraude financière** : les cryptomonnaies associées au réseau tor facilitent des transactions financières anonymes et donc favorisant des transactions illégales
# 4. **Recrutement et coordination de groupes criminels** : des forums servent à organiser des attaques informatiques, vendre des logiciels malveillants ou recruter des complices pour des activités illégales.
# 5. **Propagation de désinformation ou théories du complot extrêmes** : l'anonymat et l’absence de modération favorisent la diffusion de contenus haineux, racistes ou conspirationnistes sans contrôle.

# %% [markdown]
# ## Quels sont les services que l'on trouve sur le Dark Net ?

# %% [markdown]
# ## Liens
#
# - TorLi : liens vivants sur le dark net
# - Tails : système d'exploitation "live" permettant de se protéger contre la censure et la surveillance
# - securedrop et https://ensecurite.sourcesure.eu/#/ : canaux officiels sécurisés permettant de fuiter des informations sensibles de manière anonyme et sécurisée

# %% [markdown]
# ## Termes à définit
#
# - `.onion` sites
# - escrow (dépôt fiduciaire)
# - cryptocurrencies (BTC, Monero qui est meilleur, ...)
# - moteurs de recherche en onion ?

# %% [markdown]
# ## Le cas Alphabay
